# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,6])
ypoints = np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.random.rand(10)
ypoints = np.random.rand(10)
plt.plot(xpoints,ypoints)
plt.show()

# %%
ypoints=np.array([3,8,1,10])
#plt.plot(ypoints,linestyle='dotted')
plt.plot(ypoints,linestyle='dashed')
plt.show()

# %%
#(actual value-predicted value ka square)^1/2- square root mean
#x=np.array([5,7,8,7,2,9,3,12,11,9,6])
#y=np.array([99,88,23,45,67,12,90,34,54,85,70])
x=np.random.rand(10)
y=np.random.rand(10)
plt.scatter(x,y)
plt.show()

# %%
#draw two scatter plots in one image
x=np.random.rand(10)
y=np.random.rand(10)
plt.scatter(x,y)

x=np.random.rand(10)
y=np.random.rand(10)
plt.scatter(x,y)

plt.show()

# %%
x=np.array(["java","c++","c","python"])
y=np.array([40,18,10,80])
#plt.bar(x,y)
plt.barh(x,y)
plt.show()

# %%
x=np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
y=np.array([35,25,25,15])
plt.pie(y)
plt.show()

# %%
y=np.array([35,25,25,15])
myl=["Apples","Grapes","Cheries","Dates"]
plt.pie(y,labels=myl)
plt.legend()

plt.show()

# %%
import pandas as pd
df=pd.read_csv("titanic-dataset.csv")

df.columns
print(df.to_string())
# Out:
#      PassengerId  Survived  Pclass                                                                                Name     Sex    Age  SibSp  Parch              Ticket      Fare            Cabin Embarked
# 0              1         0       3                                                             Braund, Mr. Owen Harris    male  22.00      1      0           A/5 21171    7.2500              NaN        S
# 1              2         1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.00      1      0            PC 17599   71.2833              C85        C
# 2              3         1       3                                                              Heikkinen, Miss. Laina  female  26.00      0      0    STON/O2. 3101282    7.9250              NaN        S
# ...

# %%
#df.groupby(['Sex']).count()
y=df.loc[:,['Sex','PassengerId']].groupby('Sex').count()
plt.pie(y['Sex'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# The above exception was the direct cause of the following exception:
#
# ...
